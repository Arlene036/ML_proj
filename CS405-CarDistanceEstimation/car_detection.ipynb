# %% [markdown]
# # Car detection and estimate Distance
#
# envorienmen: py39

# %%
pip install -qr requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignore distutils configs in setup.cfg due to encoding errors.
#   WARNING: Ignore distutils configs in setup.cfg due to encoding errors.
#   WARNING: Ignore distutils configs in setup.cfg due to encoding errors.
#   WARNING: Ignore distutils configs in setup.cfg due to encoding errors.
# WARNING: Ignore distutils configs in setup.cfg due to encoding errors.

# %%
# weights: 训练好的yolo5模型； source：要检测的视频/图片
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
# Out:
# detect: weights=['yolov5s.pt'], source=data/images, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  2022-12-11 Python-3.9.13 torch-1.12.1 CUDA:0 (NVIDIA GeForce MX350, 2048MiB)
#
# ...
#
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
#   8%|▊         | 1.09M/14.1M [00:00<00:01, 11.0MB/s]
#  30%|██▉       | 4.20M/14.1M [00:00<00:00, 23.5MB/s]
#  51%|█████     | 7.18M/14.1M [00:00<00:00, 27.0MB/s]
#  69%|██████▉   | 9.77M/14.1M [00:00<00:00, 25.9MB/s]
#  92%|█████████▏| 13.0M/14.1M [00:00<00:00, 28.7MB/s]
# 100%|██████████| 14.1M/14.1M [00:00<00:00, 27.0MB/s]
#
# Fusing layers...
# ...

# %%
# add distance
# !python detect.py --weights yolov5s.pt --source data/car_detection/car.mp4
# Out:
# detect: weights=['yolov5s.pt'], source=data/car_detection/car.mp4, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  2022-12-11 Python-3.9.13 torch-1.12.1 CUDA:0 (NVIDIA GeForce MX350, 2048MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# video 1/1 (1/327) E:\Uni\work\grade3.1\machine learning\final_proj\stage2\distance\yolov5-master\data\car_detection\car.mp4: 384x640 21 cars, 1 train, 3 trucks, 26.9ms
# video 1/1 (2/327) E:\Uni\work\grade3.1\machine learning\final_proj\stage2\distance\yolov5-master\data\car_detection\car.mp4: 384x640 21 cars, 1 train, 3 trucks, 21.9ms
# ...

# %%
# add distance, 用自动驾驶的角度; foc: 相机焦距
# !python detect.py --weights yolov5s.pt --source data/car_detection/car1.mp4 --foc 1200
# Out:
# detect: weights=['yolov5s.pt'], source=data/car_detection/car1.mp4, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, foc=1200.0
# YOLOv5  2022-12-11 Python-3.9.13 torch-1.12.1 CUDA:0 (NVIDIA GeForce MX350, 2048MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# video 1/1 (1/38) E:\Uni\work\grade3.1\machine learning\final_proj\stage2\distance\yolov5-master\data\car_detection\car1.mp4: 384x640 3 cars, 30.9ms
# video 1/1 (2/38) E:\Uni\work\grade3.1\machine learning\final_proj\stage2\distance\yolov5-master\data\car_detection\car1.mp4: 384x640 3 cars, 21.9ms
# ...

# %% [markdown]
# ----

# %% [markdown]
# self-recorded
#
# 调试焦距
# https://blog.csdn.net/XiaoLanZi7k7k/article/details/126822650

# %%
# add distance, 用自动驾驶的角度; foc: 相机焦距
# !python detect.py --weights yolov5s.pt --source data/video/1.mp4 --foc 1200
# Out:
# detect: weights=['yolov5s.pt'], source=data/video/1.mp4, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, foc=1200.0
# YOLOv5  2022-12-11 Python-3.9.13 torch-1.12.1 CUDA:0 (NVIDIA GeForce MX350, 2048MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# video 1/1 (1/2308) E:\Uni\work\grade3.1\machine learning\final_proj\stage2\distance\yolov5-master\data\video\1.mp4: 640x384 (no detections), 54.0ms
# video 1/1 (2/2308) E:\Uni\work\grade3.1\machine learning\final_proj\stage2\distance\yolov5-master\data\video\1.mp4: 640x384 (no detections), 33.9ms
# ...

# %%
# add distance, cut down 公交车顶部的“横线”，它会变成正的。
# !python detect.py --weights yolov5s.pt --source data/video/4.mp4 --foc 1200
# Out:
# detect: weights=['yolov5s.pt'], source=data/video/4.mp4, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, foc=1200.0
# YOLOv5  2022-12-11 Python-3.9.13 torch-1.12.1 CUDA:0 (NVIDIA GeForce MX350, 2048MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# video 1/1 (1/2232) E:\Uni\work\grade3.1\machine learning\final_proj\stage2\distance\yolov5-master\data\video\4.mp4: 640x480 (no detections), 42.9ms
# video 1/1 (2/2232) E:\Uni\work\grade3.1\machine learning\final_proj\stage2\distance\yolov5-master\data\video\4.mp4: 640x480 (no detections), 27.9ms
# ...
